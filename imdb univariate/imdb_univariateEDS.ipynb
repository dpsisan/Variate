# %% [markdown]
# # IMDB Univaraiate EDS
# <span style= "color:cyan"> You have the data for the 100 top-rated movies from the past decade along with various pieces of information about the movie, its actors, and the voters who have rated these movies online. In this assignment, you will try to find some interesting insights into these movies and their voters, using Python. </span>>

# %%
import warnings  # ignoring warnings yall
warnings.filterwarnings('ignore')

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_csv("Movie+Assignment+Data.csv")

# %%
df.head()

# %% [markdown]
# ## Gather InFO

# %%
df.info()

# %% [markdown]
# ## Check Null

# %%
df.isnull().sum()

# %%
df.duplicated().sum() #check duplicates

# %% [markdown]
# ## Classification of Numerical and categorical fields ya

# %%
df.columns ## i am having a hard time understanding the columns in the dataset, so I will check them out lol

# %%
df.sample(10) #gathers sample of 10 random rows from the dataset

# %% [markdown]
# ## Data Analysis
#
# Now that we have loaded the dataset and inspected it, we see that most of the data is in place. As of now, no data cleaning is required, so let's start with some data manipulation, analysis, and visualisation to get various insights about the data.

# %% [markdown]
# ### task1
# I see that the numbers in budget and gross are big so lemme just change then into Millions.

# %%
df["Gross"] = df["Gross"] / 1000000 # converting gross to millions for better visualization
df["budget"] = df["budget"] / 1000000 # converting budget to millions for better visualization

# %%
df.tail()

# %% [markdown]
# ## TAsk 2
# Create a new column called profit which contains the difference of the two columns: gross and budget.
# Sort the dataframe using the profit column as reference.
# Extract the top ten profiting movies in descending order and store them in a new dataframe - top10.
# Plot a scatter or a joint plot between the columns budget and profit and write a few words on what you observed.
# Extract the movies with a negative profit and store them in a new dataframe - neg_profit

# %%
df["Profit"]= df["Gross"] - df["budget"] 
df

# %%
top10 = df.sort_values(by = 'Profit', ascending = False).head(10)
print(top10[["Profit"]])

# %% [markdown]
# # Scatter plot to check the reln between GRoss & budget

# %%
plt = sns.scatterplot(x= 'budget', y= 'Gross', data = df)

# %%
#find the movies with negative profit

neg_movies= df[df["Profit"] < 0]
neg_movies.head(2)

# %% [markdown]
#  ##Can you spot the movie Tangled in the dataset? You may be aware of the movie 'Tangled'. Although its one of the highest grossing movies of all time, it has negative profit as per this result. If you cross check the gross values of this movie (link: https://www.imdb.com/title/tt0398286/), you can see that the gross in the dataset accounts only for the domestic gross and not the worldwide gross. This is true for may other movies also in the list.
#
# #task3: The General Audience and the Critics
# You might have noticed the column MetaCritic in this dataset. This is a very popular website where an average score is determined through the scores given by the top-rated critics. Second, you also have another column IMDb_rating which tells you the IMDb rating of a movie. This rating is determined by taking the average of hundred-thousands of ratings from the general audience.
#
# As a part of this subtask, you are required to find out the highest rated movies which have been liked by critics and audiences alike.
#
# Firstly you will notice that the MetaCritic score is on a scale of 100 whereas the IMDb_rating is on a scale of 10. First convert the MetaCritic column to a scale of 10.
# Now, to find out the movies which have been liked by both critics and audiences alike and also have a high rating overall, you need to -
# Create a new column Avg_rating which will have the average of the MetaCritic and Rating columns
# Retain only the movies in which the absolute difference(using abs() function) between the IMDb_rating and Metacritic columns is less than 0.5. Refer to this link to know how abs() funtion works - https://www.geeksforgeeks.org/abs-in-python/ .
# Sort these values in a descending order of Avg_rating and retain only the movies with a rating equal to higher than 8 and store these movies in a new dataframe UniversalAcclaim.

# %%
df["MetaCritic"] = df["MetaCritic"] /10 ## my dataset has no imdb raiting column, so I will use the meta critic column to calculate the average rating of the movies.

df["avg_rating"] = df["MetaCritic"]+df["VotesUS"] / 2

# %%
df = df.sort_values( by = "avg_rating", ascending = False)
df

# %% [markdown]
# # Find the Most Popular Trios - I
# You're a producer looking to make a blockbuster movie. There will primarily be three lead roles in your movie and you wish to cast the most popular actors for it. Now, since you don't want to take a risk, you will cast a trio which has already acted in together in a movie before. The metric that you've chosen to check the popularity is the Facebook likes of each of these actors.
# ##
# The dataframe has three columns to help you out for the same, viz. actor_1_facebook_likes, actor_2_facebook_likes, and actor_3_facebook_likes. Your objective is to find the trios which has the most number of Facebook likes combined. That is, the sum of actor_1_facebook_likes, actor_2_facebook_likes and actor_3_facebook_likes should be maximum. Find out the top 5 popular trios, and output their names in a list.

# %%
total_actor_likes = df["actor_1_facebook_likes"] + df["actor_2_facebook_likes"] + df["actor_3_facebook_likes"]
df["total_actor_likes"] = total_actor_likes

df = df.sort_values( by = "total_actor_likes", ascending = False)
df.head(5)

# %%
df.columns

# %% [markdown]
# ## Subtask 2.6: Runtime Analysis
# <span style = "color : cyan" >
# There is a column named Runtime in the dataframe which primarily shows the length of the movie. It might be intersting to see how this variable this distributed. Plot a histogram or distplot of seaborn to find the Runtime range most of the movies fall into.</span>

# %%
plt = sns.histplot(df["Runtime"], bins = 20)

# %% [markdown]
# # R-Rated Movies
# Although R rated movies are restricted movies for the under 18 age group, still there are vote counts from that age group. Among all the R rated movies that have been voted by the under-18 age group, find the top 10 movies that have the highest number of votes i.e.CVotesU18 from the movies dataframe. Store these in a dataframe named PopularR.

# %%
PopularR = df[df["content_rating"] == "R"]
PopularR = PopularR.sort_values(by = "CVotesU18", ascending = False)[["Title", "CVotesU18", "content_rating"]]
PopularR.head(10)

# %% [markdown]
# #  Demographic analysis
# If you take a look at the last columns in the dataframe, most of these are related to demographics of the voters (in the last subtask, i.e., 2.8, you made use one of these columns - CVotesU18). We also have three genre columns indicating the genres of a particular movie. We will extensively use these columns for the third and the final stage of our assignment wherein we will analyse the voters across all demographics and also see how these vary across various genres. So without further ado, let's get started with demographic analysis.
#
# ## Subtask 3.1 Combine the Dataframe by Genres
# There are 3 columns in the dataframe - genre_1, genre_2, and genre_3. As a part of this subtask, you need to aggregate a few values over these 3 columns.
#
# ###
#
#  First create a new dataframe df_by_genre that contains genre_1, genre_2, and genre_3 and all the columns related to CVotes/Votes from the movies data frame. There are 47 columns to be extracted in total.
#
# Now, Add a column called cnt to the dataframe df_by_genre and initialize it to one. You will realise the use of this column by the end of this subtask.
# First group the dataframe df_by_genre by genre_1 and find the sum of all the numeric columns such as cnt, columns related to CVotes and Votes columns and store it in a dataframe df_by_g1.
# Perform the same operation for genre_2 and genre_3 and store it dataframes df_by_g2 and df_by_g3 respectively.
# Now that you have 3 dataframes performed by grouping over genre_1, genre_2, and genre_3 separately, it's time to combine them. For this, add the three dataframes and store it in a new dataframe df_add, so that the corresponding values of Votes/CVotes get added for each genre.There is a function called add() in pandas which lets you do this. You can refer to this link to see how this function works. https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.add.html
# The column cnt on aggregation has basically kept the track of the number of occurences of each genre.Subset the genres that have atleast 10 movies into a new dataframe genre_top10 based on the cnt column value.
# Now, take the mean of all the numeric columns by dividing them with the column value cnt and store it back to the same dataframe. We will be using this dataframe for further analysis in this task unless it is explicitly mentioned to use the dataframe movies.
# Since the number of votes can't be a fraction, type cast all the CVotes related columns to integers. Also, round off all the Votes related columns upto two digits after the decimal point.

# %%
df.columns

# %%
df_by_genre=df.loc[:,"CVotes10":"VotesnUS"]
df_by_genre[["genre_1","genre_2","genre_3"]]=df[["genre_1","genre_2","genre_3"]]
df_by_genre

# %%
df_by_genre["cnt"]=1

# %%
df_by_genre[["genre_1","genre_2","genre_3"]]

# %%
df_by_g1 = df_by_genre.groupby("genre_1").sum(numeric_only=True)
df_by_g2 = df_by_genre.groupby("genre_2").sum(numeric_only=True)
df_by_g3 = df_by_genre.groupby("genre_3").sum(numeric_only=True)
# Out:
#     CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  CVotes04  \
# 2      23325     29830     40564     20296      5842      1669       558
# 27    584839    485218    304457    130972     46393     20595     10050
# 14     91765    127521    183578    104658     33027     10059      3710
# 4      18191     33532     46596     29626     11879      4539      1976
# 8     380589    341965    281426    134959     50406     20106      9589
# ..       ...       ...       ...       ...       ...       ...       ...
# 97    155391    161810    166378     99402     40734     18060      8751
# 34     89986    127616    169693    122275     57564     25393     12286
# 0      74245     71191     64640     38831     17377      8044      3998
# 3      55533     87850    109536     65440     26913     10556      5057
# 6      38952     51465    102744     83322     32430     10744      3786
#
#     CVotes03  CVotes02  CVotes01  ...  Votes45A  Votes45AM  Votes45AF  \
# 2        309       182       493  ...       8.0        7.9        8.4
# 27      6631      5243     15365  ...       8.1        8.1        8.0
# 14      1903      1225      3301  ...       7.7        7.7        7.9
# 4       1233       888      1834  ...       7.6        7.6        7.6
# 8       5713      4073     11988  ...       7.9        7.9        7.9
# ..       ...       ...       ...  ...       ...        ...        ...
# 97      5970      4489     15768  ...       7.9        7.8        8.2
# 34      7868      5751     12473  ...       7.7        7.7        7.5
# 0       2839      2407      6802  ...       7.6        7.6        7.5
# 3       3083      2194      4734  ...       7.6        7.6        7.7
# 6       1854      1038      2667  ...       7.5        7.4        7.8
#
#     Votes1000  VotesUS  VotesnUS    genre_1    genre_2   genre_3  cnt
# 2         7.1      8.1       8.0  Biography      Drama       NaN    1
# 27        8.2      8.7       8.8     Action  Adventure    Sci-Fi    1
# 14        7.4      8.1       7.9     Action  Adventure    Sci-Fi    1
# 4         7.1      7.9       7.8      Drama        NaN       NaN    1
# 8         7.8      8.4       8.4     Action   Thriller       NaN    1
# ..        ...      ...       ...        ...        ...       ...  ...
# 97        7.7      8.2       7.9     Action  Adventure   Fantasy    1
# 34        7.5      7.9       7.8      Drama     Sci-Fi  Thriller    1
# 0         7.1      8.3       8.1     Comedy      Drama     Music    1
# 3         7.3      8.0       7.9      Drama    Mystery    Sci-Fi    1
# 6         7.1      7.6       7.4     Action  Adventure   Fantasy    1
#
# [100 rows x 48 columns]

# %%
df_by_g1
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_1
# Action      2928407   3261919   4247693   2662020    986774    364234
# Adventure   1058779   1179818   1560541    966275    365486    136985
# Animation    681562    798227   1153214    722782    251076     83069
# Biography    666831   1088430   1654704    962977    306247    100005
# Comedy       371217    496905    770395    518566    205434     81933
# Crime        383290    690221   1083469    627593    206756     71460
# Drama       1080725   1494053   1827363   1078966    417205    163874
# Mystery      150405    230844    278844    132349     45167     15615
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes3044F  Votes45A  \
# genre_1                                            ...
# Action       156150     89483     61975    162426  ...       210.0     206.5
# Adventure     58559     33174     22018     48100  ...        93.5      92.0
# Animation     30718     15733     10026     25193  ...        87.8      84.5
# Biography     38874     21536     15365     37469  ...       101.3     100.5
# Comedy        35788     20965     15286     33241  ...        68.9      67.7
# Crime         30336     17190     11757     25839  ...        68.8      68.7
# Drama         75525     45846     32068     71464  ...       139.7     137.7
# Mystery        7061      3780      2662      4703  ...         8.0       7.5
#
#            Votes45AM  Votes45AF  Votes1000  VotesUS  VotesnUS  \
# genre_1
# Action         206.0      209.0      197.2    215.8     209.5
# Adventure       91.6       93.8       88.9     95.3      93.5
# Animation       84.1       86.7       80.0     87.6      86.1
# Biography      100.0      102.9       94.7    103.3     101.5
# Comedy          67.5       68.7       62.7     70.9      69.4
# Crime           68.6       69.6       66.3     71.9      70.1
# Drama          137.2      138.7      130.0    143.2     141.1
# Mystery          7.4        7.6        7.6      7.8       8.1
#
#                                                      genre_2  \
# genre_1
# Action     AdventureAdventureThrillerSci-FiAdventureAdven...
# Adventure  DramaDramaDramaComedyDramaComedyDramaFamilyBio...
# Animation  AdventureAdventureActionActionActionAdventureA...
# Biography  DramaComedyDramaComedyDramaDramaDramaDramaDram...
# Comedy      DramaDramaDramaDramaDramaHorrorDramaFantasyDrama
# Crime          DramaDramaDramaDramaDramaDramaDramaDramaDrama
# Drama      MusicalWesternThrillerMusicRomanceHistorySport...
# Mystery                                             Thriller
#
#                                                      genre_3  cnt
# genre_1
# Action     Sci-FiSci-FiSci-FiMysterySci-FiSci-FiDramaSci-...   27
# Adventure  ThrillerFamilySci-FiDramaWesternDramaSci-FiFan...   12
# Animation  ComedyDramaAdventureAdventureAdventureComedyCo...   11
# Biography  DramaSportCrimeThrillerThrillerRomanceHistoryH...   13
# Comedy       RomanceRomanceRomanceRomanceFantasyRomanceMusic    9
# Crime      ThrillerMysteryThrillerMysteryThrillerThriller...    9
# Drama              RomanceSci-FiThrillerSci-FiThrillerSci-Fi   18
# Mystery                                                         1
#
# [8 rows x 47 columns]

# %%
df_by_g2
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_2
# Action       238060    285510    430062    260106     88580     29250
# Adventure   2297820   2548864   3271725   2055600    758009    272735
# Biography    185172    313178    576374    370003    119348     38643
# Comedy       428995    624720    854162    512668    193916     76752
# Crime         19576     40247     85359     64633     24920      8548
# Drama       1923492   2761237   4112363   2492241    853434    300100
# Family        68937     54947    102488     80465     31205     11792
# Fantasy      270616    290831    447307    291071    120920     47215
# History       15757     32840     83322     63800     19183      5178
# Horror        16572     19818     44460     35863     13456      4588
# Music        110404    161864    132656     56007     16577      6031
# Musical       54268     47750     63323     45160     22393     10744
# Mystery       85313    152619    233474    148176     55575     20135
# Romance      230425    270702    353326    215355     87701     35226
# Sci-Fi       350243    361819    433983    284879    125143     53350
# Sport         21364     28964     58237     45563     16432      5118
# Thriller     624792    709424    734770    365134    135892     52714
# War           15911     17607     32570     24461     10274      3848
# Western      234824    339329    286911    121445     38251     14227
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes3044F  Votes45A  \
# genre_2                                            ...
# Action        10820      5521      3598      8821  ...        31.8      30.5
# Adventure    113691     64623     44121    116937  ...       173.9     169.2
# Biography     14844      7974      5248     13828  ...        38.5      38.0
# Comedy        35193     20995     14798     30509  ...        53.4      53.0
# Crime          3261      1669       970      1689  ...         7.2       7.6
# Drama        124511     70205     49642    112896  ...       270.1     267.9
# Family         4808      2454      1617      4522  ...         8.1       7.4
# Fantasy       19848     10871      6885     14702  ...        23.3      23.0
# History        1657       735       419       878  ...         7.5       7.7
# Horror         1684       855       479       848  ...         7.7       7.5
# Music          2937      1859      1263      2723  ...         8.2       8.1
# Musical        5551      3484      2490      5020  ...         7.6       7.4
# Mystery        8863      5034      3359      6916  ...        15.2      15.2
# Romance       16298      9448      6708     14889  ...        38.7      37.9
# Sci-Fi        24462     15069     10747     28001  ...        15.6      15.6
# Sport          1655       848       464      1151  ...         7.4       7.3
# Thriller      25734     15558     10716     25417  ...        24.2      22.9
# War            1387       726       342       755  ...         7.7       7.6
# Western        6469      4149      3181      8065  ...         8.3       8.0
#
#            Votes45AM  Votes45AF  Votes1000  VotesUS  VotesnUS  \
# genre_2
# Action          30.4       31.4       29.0     31.8      31.1
# Adventure      168.4      172.8      162.7    176.4     171.6
# Biography       37.9       38.8       35.4     39.4      38.4
# Comedy          53.1       53.1       51.0     55.5      54.3
# Crime            7.6        7.4        7.2      7.8       7.6
# Drama          267.1      271.8      253.4    278.2     272.6
# Family           7.3        8.0        6.7      7.9       7.5
# Fantasy         22.8       23.7       22.1     23.4      23.2
# History          7.6        7.9        7.4      7.7       7.5
# Horror           7.4        7.7        7.1      7.7       7.5
# Music            8.1        8.2        8.0      8.6       8.4
# Musical          7.3        7.7        6.6      7.6       7.5
# Mystery         15.2       15.1       14.8     15.9      15.6
# Romance         37.8       37.7       35.3     39.7      39.2
# Sci-Fi          15.6       15.6       14.9     16.2      15.7
# Sport            7.3        7.5        7.1      7.9       7.5
# Thriller        22.8       22.9       23.0     24.2      24.5
# War              7.5        8.0        6.6      7.6       7.5
# Western          8.0        8.1        7.8      8.4       8.4
#
#                                                      genre_1  \
# genre_2
# Action                  AnimationAnimationAnimationAnimation
# Adventure  ActionActionAnimationActionActionActionActionA...
# Biography                  ActionActionAdventureActionAction
# Comedy     BiographyBiographyAdventureAdventureActionAdve...
# Crime                                                 Action
# Drama      BiographyComedyAdventureBiographyCrimeComedyCr...
# Family                                             Adventure
# Fantasy                             AdventureAdventureComedy
# History                                                Drama
# Horror                                                Comedy
# Music                                                  Drama
# Musical                                                Drama
# Mystery                                           DramaDrama
# Romance                            DramaDramaDramaDramaDrama
# Sci-Fi                                           ActionDrama
# Sport                                                  Drama
# Thriller                                  ActionDramaMystery
# War                                                    Drama
# Western                                                Drama
#
#                                                      genre_3  cnt
# genre_2
# Action                  AdventureAdventureAdventureAdventure    4
# Adventure  Sci-FiSci-FiComedySci-FiMysterySci-FiSci-FiSci...   22
# Biography                          DramaDramaDramaDramaDrama    5
# Comedy                      DramaCrimeDramaDramaRomanceDrama    7
# Crime                                                  Drama    1
# Drama      RomanceThrillerSportThrillerRomanceMysteryFami...   35
# Family                                               Fantasy    1
# Fantasy                                              Romance    3
# History                                             Thriller    1
# Horror                                                          1
# Music                                                           1
# Musical                                              Romance    1
# Mystery                                         Sci-FiSci-Fi    2
# Romance                                               Sci-Fi    5
# Sci-Fi                                              Thriller    2
# Sport                                                           1
# Thriller                                                        3
# War                                                             1
# Western                                                         1
#
# [19 rows x 47 columns]

# %%
df_by_g3
# Out:
#            CVotes10  CVotes09  CVotes08  CVotes07  CVotes06  CVotes05  \
# genre_3
# Adventure    238060    285510    430062    260106     88580     29250
# Comedy       583404    653362    882294    559835    200937     68167
# Crime        171660    236650    250667    129164     46715     18682
# Drama        400221    680085   1167327    748493    258717     88338
# Family        29228     40728     77893     62936     27932     11179
# Fantasy      301836    311392    442460    308676    120911     46269
# History      135504    227547    311209    159262     48678     16055
# Music         74245     71191     64640     38831     17377      8044
# Mystery      274446    443661    654167    375087    128131     44818
# Romance      319534    418790    715954    497486    193588     75675
# Sci-Fi      1975041   2169036   2569011   1517219    546668    200825
# Sport         95717    140282    214806    138600     44470     13821
# Thriller     456909    756067   1258608    810665    280154     97239
# War           36753     54703    111271     82505     30231     10553
# Western       21094     40901     91825     67175     23055      7191
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes3044F  Votes45A  \
# genre_3                                            ...
# Adventure     10820      5521      3598      8821  ...        31.8      30.5
# Comedy        26488     14258      9307     24617  ...        56.0      54.3
# Crime          8674      5854      4258      9689  ...         7.7       7.6
# Drama         35439     19075     12475     26948  ...        92.0      91.2
# Family         4664      2674      1700      3023  ...         7.4       7.5
# Fantasy       19555     11362      7808     24139  ...        31.7      30.4
# History        6307      3649      2729      8413  ...        23.8      23.3
# Music          3998      2839      2407      6802  ...         7.8       7.6
# Mystery       18755     10578      7149     17825  ...        31.5      30.4
# Romance       32615     18250     12492     25186  ...        60.9      59.9
# Sci-Fi        87463     50835     35424     86434  ...       117.6     115.5
# Sport          5155      2509      1828      4083  ...        15.2      15.2
# Thriller      39547     22382     15051     32213  ...        75.9      76.7
# War            4303      2388      1629      3246  ...         7.4       7.4
# Western        2678      1305       779      1672  ...         7.5       7.7
#
#            Votes45AM  Votes45AF  Votes1000  VotesUS  VotesnUS  \
# genre_3
# Adventure       30.4       31.4       29.0     31.8      31.1
# Comedy          54.1       55.3       51.7     56.2      55.2
# Crime            7.6        7.5        7.8      8.1       8.1
# Drama           91.0       92.7       86.1     94.5      92.3
# Family           7.5        7.6        7.4      7.7       7.5
# Fantasy         30.0       31.8       28.4     31.5      30.5
# History         23.1       24.2       22.0     24.5      23.7
# Music            7.6        7.5        7.1      8.3       8.1
# Mystery         30.3       31.3       29.3     31.9      31.3
# Romance         59.7       61.2       54.6     62.1      60.9
# Sci-Fi         115.2      115.9      113.0    121.3     118.3
# Sport           15.2       15.0       14.2     16.0      15.6
# Thriller        76.5       77.8       73.2     78.9      77.0
# War              7.4        7.4        6.8      7.6       7.5
# Western          7.7        7.7        7.3      7.9       7.6
#
#                                                      genre_1  \
# genre_3
# Adventure               AnimationAnimationAnimationAnimation
# Comedy     AnimationActionAnimationAnimationAnimationAnim...
# Crime                                              Biography
# Drama      BiographyActionAnimationAdventureActionAdventu...
# Family                                             Adventure
# Fantasy                          AdventureComedyActionAction
# History                              BiographyBiographyCrime
# Music                                                 Comedy
# Mystery                                ActionCrimeCrimeCrime
# Romance    ComedyDramaComedyBiographyActionComedyComedyCo...
# Sci-Fi     ActionActionActionActionActionActionActionAdve...
# Sport                                        BiographyAction
# Thriller   AdventureCrimeCrimeBiographyDramaBiographyCrim...
# War                                                   Action
# Western                                            Adventure
#
#                                                      genre_2  cnt
# genre_3
# Adventure                           ActionActionActionAction    4
# Comedy     AdventureAdventureAdventureAdventureAdventureA...    7
# Crime                                                 Comedy    1
# Drama      ComedyBiographyAdventureComedyBiographyComedyA...   12
# Family                                                 Drama    1
# Fantasy                        FamilyDramaAdventureAdventure    4
# History                                      DramaDramaDrama    3
# Music                                                  Drama    1
# Mystery                             AdventureDramaDramaDrama    4
# Romance        DramaMusicalDramaDramaComedyDramaDramaFantasy    8
# Sci-Fi     AdventureAdventureAdventureAdventureAdventureA...   15
# Sport                                             DramaDrama    2
# Thriller   DramaDramaDramaDramaHistoryDramaDramaDramaAdve...   10
# War                                                    Drama    1
# Western                                                Drama    1
#
# [15 rows x 47 columns]

# %%
# Add the grouped data frames and store it in a new data frame
df_add=df_by_g1.add(df_by_g2,fill_value=0)
df_add=df_add.add(df_by_g3,fill_value=0)
df_add
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[221], line 2
#       1 # Add the grouped data frames and store it in a new data frame
# ----> 2 df_add=df_by_g1.add(df_by_g2,fill_value=0)
#       3 df_add=df_add.add(df_by_g3,fill_value=0)
#       4 df_add
#
# File d:\anaconda\Lib\site-packages\pandas\core\frame.py:9906, in DataFrame.add(self, other, axis, level, fill_value)
#    9902     @Appender(ops.make_flex_doc("add", "dataframe"))
#    9903     def add(
#    9904         self, other, axis: Axis = "columns", level=None, fill_value=None
#    9905     ) -> DataFrame:
# -> 9906         return self._flex_arith_method(
#    9907             other, operator.add, level=level, fill_value=fill_value, axis=axis
#    9908         )
#
# File d:\anaconda\Lib\site-packages\pandas\core\frame.py:9521, in DataFrame._flex_arith_method(self, other, op, axis, level, fill_value)
#    9517
#    9518         with np.errstate(all="ignore"):
#    9519             if isinstance(other, DataFrame):
#    9520                 # Another DataFrame
# -> 9521                 new_data = self._combine_frame(other, op, fill_value)
#    9522
#    9523             elif isinstance(other, Series):
#    9524                 new_data = self._dispatch_frame_op(other, op, axis=axis)
#
# File d:\anaconda\Lib\site-packages\pandas\core\frame.py:9243, in DataFrame._combine_frame(self, other, func, fill_value)
#    9239                 # left._binop(right, func, fill_value=fill_value)
#    9240                 left, right = ops.fill_binop(left, right, fill_value)
#    9241                 return func(left, right)
#    9242
# -> 9243         new_data = self._dispatch_frame_op(other, _arith_op)
#    9244         return new_data
#
# File d:\anaconda\Lib\site-packages\pandas\core\frame.py:9194, in DataFrame._dispatch_frame_op(self, right, func, axis)
#    9190             #  fails in cases with empty columns reached via
#    9191             #  _frame_arith_method_with_reindex
#    9192
#    9193             # TODO operate_blockwise expects a manager of the same type
# -> 9194             bm = self._mgr.operate_blockwise(
#    9195                 right._mgr,
#    9196                 array_op,
#    9197             )
#
# File d:\anaconda\Lib\site-packages\pandas\core\internals\managers.py:1691, in BlockManager.operate_blockwise(self, other, array_op)
#    1687 def operate_blockwise(self, other: BlockManager, array_op) -> BlockManager:
#    1688     """
#    1689     Apply array_op blockwise with another (aligned) BlockManager.
#    1690     """
# -> 1691     return operate_blockwise(self, other, array_op)
#
# File d:\anaconda\Lib\site-packages\pandas\core\internals\ops.py:65, in operate_blockwise(left, right, array_op)
#      63 res_blks: list[Block] = []
#      64 for lvals, rvals, locs, left_ea, right_ea, rblk in _iter_block_pairs(left, right):
# ---> 65     res_values = array_op(lvals, rvals)
#      66     if (
#      67         left_ea
#      68         and not right_ea
#      69         and hasattr(res_values, "reshape")
#      70         and not is_1d_only_ea_dtype(res_values.dtype)
#      71     ):
#      72         res_values = res_values.reshape(1, -1)
#
# File d:\anaconda\Lib\site-packages\pandas\core\frame.py:9240, in DataFrame._combine_frame.<locals>._arith_op(left, right)
#    9236             def _arith_op(left, right):
#    9237                 # for the mixed_type case where we iterate over columns,
#    9238                 # _arith_op(left, right) is equivalent to
#    9239                 # left._binop(right, func, fill_value=fill_value)
# -> 9240                 left, right = ops.fill_binop(left, right, fill_value)
#    9241                 return func(left, right)
#
# File d:\anaconda\Lib\site-packages\pandas\core\ops\array_ops.py:110, in fill_binop(left, right, fill_value)
#     107     if right_mask.any():
#     108         # Avoid making a copy if we can
#     109         right = right.copy()
# --> 110         right[right_mask & mask] = fill_value
#     112 return left, right
#
# File d:\anaconda\Lib\site-packages\pandas\core\arrays\arrow\array.py:2237, in ArrowExtensionArray.__setitem__(self, key, value)
#    2234     key = key[0]
#    2236 key = check_array_indexer(self, key)
# -> 2237 value = self._maybe_convert_setitem_value(value)
#    2239 if com.is_null_slice(key):
#    2240     # fast path (GH50248)
#    2241     if (
#    2242         isinstance(value, (pa.Array, pa.ChunkedArray))
#    2243         and value.type == self._pa_array.type
#    2244         and len(value) == len(self)
#    2245     ):
#
# File d:\anaconda\Lib\site-packages\pandas\core\arrays\string_arrow.py:287, in ArrowStringArray._maybe_convert_setitem_value(self, value)
#     285         value = None
#     286     elif not isinstance(value, str):
# --> 287         raise TypeError(
#     288             f"Invalid value '{value}' for dtype 'str'. Value should be a "
#     289             f"string or missing value, got '{type(value).__name__}' instead."
#     290         )
#     291 elif isinstance(value, type(self)):
#     292     pass
#
# TypeError: Invalid value '0' for dtype 'str'. Value should be a string or missing value, got 'int' instead.
